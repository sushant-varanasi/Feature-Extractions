# %% [markdown]
# ## RGB Image

# %%
from PIL import Image, ImageFilter
 
 
image = Image.open("car.jpeg")

image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x169 at 0x7F2C70001450>

# %% [markdown]
# ## Edge Detection

# %%
image2 = image.convert("L")
 
image2 = image2.filter(ImageFilter.FIND_EDGES)

image2.save(r"Edge_Sample.png")

image2
# Out:
# <PIL.Image.Image image mode=L size=299x169 at 0x7F2C72E7C710>

# %% [markdown]
# ## RGB to GrayScale Conversion

# %%
from PIL import ImageOps

gray_image = ImageOps.grayscale(image)
gray_image
# Out:
# <PIL.Image.Image image mode=L size=299x169 at 0x7F2C6CD153D0>

# %% [markdown]
# ## HOG - Histogram of Oriented Gradients

# %%
#importing required libraries
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt

# reading the image
img = imread('car.jpeg')
plt.axis("off")
plt.imshow(img)
print(img.shape)

resized_img = img
# resized_img = resize(img, (64*4, 100*4))
# plt.axis("off")
# plt.imshow(resized_img)
# print(resized_img.shape)

#creating hog features
fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                	cells_per_block=(2, 2), visualize=True, multichannel=True)
plt.axis("off")
plt.imshow(hog_image, cmap="ocean")
# Out:
# (169, 299, 3)

# %% [markdown]
# ## Tresholds

# %%
import matplotlib
import matplotlib.pyplot as plt

from skimage import data
from skimage.filters import try_all_threshold

img = data.camera()

fig, ax = try_all_threshold(img, figsize=(10, 8), verbose=False)
plt.show()
